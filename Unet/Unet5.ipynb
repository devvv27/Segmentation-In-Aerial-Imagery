# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
import seaborn as sns

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch, dropout_rate=0.1, use_dropout=True):
        super().__init__()
        layers = [
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        ]
        if use_dropout:
            layers.append(nn.Dropout2d(dropout_rate))
        
        layers.extend([
            nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        ])
        if use_dropout:
            layers.append(nn.Dropout2d(dropout_rate))
        
        self.double_conv = nn.Sequential(*layers)

    def forward(self, x):
        return self.double_conv(x)

class UNet(nn.Module):
    """U-Net with a configurable depth: one encoder/decoder level per entry in `features`.
    Same dropout pattern as the 4-level U-Net: no dropout in the shallow encoder blocks,
    dropout in the deepest encoder block, the bottleneck and every decoder block."""
    def __init__(self, in_channels=3, out_channels=1, features=[32, 64, 128, 256, 512], dropout_rate=0.15):
        super().__init__()
        self.encoders = nn.ModuleList()
        self.pools = nn.ModuleList()
        prev = in_channels
        for i, f in enumerate(features):
            deepest = (i == len(features) - 1)
            self.encoders.append(DoubleConv(prev, f, dropout_rate, use_dropout=deepest))
            self.pools.append(nn.MaxPool2d(2))
            prev = f

        self.bottleneck = DoubleConv(features[-1], features[-1]*2, dropout_rate=0.2, use_dropout=True)

        self.ups = nn.ModuleList()
        self.decoders = nn.ModuleList()
        up_in = features[-1]*2
        for f in reversed(features):
            self.ups.append(nn.ConvTranspose2d(up_in, f, kernel_size=2, stride=2))
            self.decoders.append(DoubleConv(f*2, f, dropout_rate, use_dropout=True))
            up_in = f

        self.final_conv = nn.Conv2d(features[0], out_channels, kernel_size=1)

    def forward(self, x):
        skips = []
        for enc, pool in zip(self.encoders, self.pools):
            x = enc(x)
            skips.append(x)
            x = pool(x)

        x = self.bottleneck(x)

        for up, dec, skip in zip(self.ups, self.decoders, reversed(skips)):
            x = up(x)
            x = torch.cat([x, skip], dim=1)
            x = dec(x)

        return self.final_conv(x)

IMG_EXTS = ('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')

def find_pv01_pairs(root_dir):
    """Walk root_dir and pair every 'NAME.<ext>' image with its 'NAME_label.<ext>' mask.
    Returns {group_name: [(image_path, label_path), ...]} where group_name is the
    rooftop folder (PV01_Rooftop_Brick, PV01_Rooftop_FlatConcrete, ...)."""
    groups = {}
    for folder, _, files in sorted(os.walk(root_dir)):
        by_stem = {os.path.splitext(f)[0]: f for f in sorted(files) if f.lower().endswith(IMG_EXTS)}
        rel = os.path.relpath(folder, root_dir)
        group = rel.split(os.sep)[0]
        for stem, fname in by_stem.items():
            if stem.endswith('_label'):
                continue
            lbl = by_stem.get(stem + '_label')
            if lbl is not None:
                groups.setdefault(group, []).append((os.path.join(folder, fname), os.path.join(folder, lbl)))
    return groups

def build_pv01_splits(root_dir, val_frac=0.15, test_frac=0.15, seed=42):
    """PV01 ships without a train/val/test split, so make a fixed, seeded one.
    The split is done per rooftop folder so all three types appear in every split."""
    groups = find_pv01_pairs(root_dir)
    assert len(groups) > 0, f"No image/_label pairs found under {root_dir}"
    rng = np.random.RandomState(seed)
    train, val, test = [], [], []
    for g in sorted(groups):
        pairs = groups[g]
        idx = rng.permutation(len(pairs))
        n_test = int(round(len(pairs) * test_frac))
        n_val = int(round(len(pairs) * val_frac))
        test += [pairs[i] for i in idx[:n_test]]
        val += [pairs[i] for i in idx[n_test:n_test + n_val]]
        train += [pairs[i] for i in idx[n_test + n_val:]]
        print(f"{g}: {len(pairs)} pairs")
    return train, val, test

class PV01Dataset(Dataset):
    def __init__(self, pairs, transform=None, img_size=(256, 256)):
        self.pairs = pairs
        self.transform = transform
        self.img_size = img_size

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        img_path, label_path = self.pairs[idx]

        img = Image.open(img_path).convert('RGB').resize(self.img_size)
        label = Image.open(label_path).convert('L').resize(self.img_size, Image.NEAREST)

        if self.transform:
            img = self.transform(img)
        else:
            img = transforms.ToTensor()(img)

        # binary mask: any non-zero pixel is solar panel (works for 0/255 and 0/1 masks)
        label = torch.from_numpy((np.array(label) > 0).astype(np.float32)).unsqueeze(0)

        return img, label

class EarlyStopping:
    def __init__(self, patience=15, min_delta=1e-4, restore_best_weights=True):
        self.patience = patience
        self.min_delta = min_delta
        self.restore_best_weights = restore_best_weights
        self.best_loss = None
        self.counter = 0
        self.best_weights = None
        
    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(model)
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
            self.save_checkpoint(model)
        else:
            self.counter += 1
            
        if self.counter >= self.patience:
            if self.restore_best_weights:
                model.load_state_dict(self.best_weights)
            return True
        return False
    
    def save_checkpoint(self, model):
        self.best_weights = model.state_dict().copy()

def dice_coef(pred, target, smooth=1e-6):
    pred = pred.contiguous()
    target = target.contiguous()
    intersection = (pred * target).sum(dim=(2,3))
    denom = pred.sum(dim=(2,3)) + target.sum(dim=(2,3))
    dice = (2. * intersection + smooth) / (denom + smooth)
    return dice.mean()

class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super().__init__()
        self.smooth = smooth

    def forward(self, pred, target):
        dice = dice_coef(pred, target, smooth=self.smooth)
        return 1.0 - dice

def combined_loss(logits, mask, bce_weight=0.6, dice_weight=0.4):
    bce_loss = nn.BCEWithLogitsLoss()
    bce = bce_loss(logits, mask)
    probs = torch.sigmoid(logits)
    dice = DiceLoss()(probs, mask)
    return bce_weight * bce + dice_weight * dice

@torch.no_grad()
def compute_metrics_batch(logits, masks, thresh=0.5):
    probs = torch.sigmoid(logits)
    preds = (probs >= thresh).float()
    preds_flat = preds.view(-1).cpu().numpy()
    masks_flat = masks.view(-1).cpu().numpy()
    
    unique_preds = np.unique(preds_flat)
    unique_masks = np.unique(masks_flat)
    
    if len(unique_preds) == 1 and len(unique_masks) == 1:
        if unique_preds[0] == unique_masks[0]:
            if unique_preds[0] == 1:
                tp, fp, fn, tn = len(preds_flat), 0, 0, 0
            else:
                tp, fp, fn, tn = 0, 0, 0, len(preds_flat)
        else:
            if unique_preds[0] == 1:
                tp, fp, fn, tn = 0, len(preds_flat), 0, 0
            else:
                tp, fp, fn, tn = 0, 0, len(preds_flat), 0
    else:
        cm = confusion_matrix(masks_flat, preds_flat, labels=[0,1])
        if cm.shape == (2, 2):
            tn, fp, fn, tp = cm.ravel()
        else:
            if cm.shape == (1, 1):
                if unique_masks[0] == 0:
                    tn, fp, fn, tp = cm[0,0], 0, 0, 0
                else:
                    tn, fp, fn, tp = 0, 0, 0, cm[0,0]
            else:
                tn, fp, fn, tp = 0, 0, 0, 0
    
    eps = 1e-8
    iou = tp / (tp + fp + fn + eps)
    iou_bg = tn / (tn + fp + fn + eps)
    miou = (iou + iou_bg) / 2
    dice = (2 * tp) / (2 * tp + fp + fn + eps)
    precision = tp / (tp + fp + eps)
    recall = tp / (tp + fn + eps)
    f1 = 2 * precision * recall / (precision + recall + eps)
    acc = (tp + tn) / (tp + tn + fp + fn + eps)
    
    return {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp),
            "iou": float(iou), "miou": float(miou), "dice": float(dice), "precision": float(precision),
            "recall": float(recall), "f1": float(f1), "acc": float(acc)}

def train_one_epoch(model, loader, optimizer, scheduler=None):
    model.train()
    running_loss = 0.0
    running_acc = 0.0
    for imgs, masks in tqdm(loader, desc="Train batch"):
        imgs = imgs.to(device)
        masks = masks.to(device)
        optimizer.zero_grad()
        logits = model(imgs)
        loss = combined_loss(logits, masks)
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        running_loss += loss.item() * imgs.size(0)
        
        metrics = compute_metrics_batch(logits, masks)
        running_acc += metrics['acc'] * imgs.size(0)
    
    if scheduler is not None:
        scheduler.step()
    
    epoch_loss = running_loss / len(loader.dataset)
    epoch_acc = running_acc / len(loader.dataset)
    return epoch_loss, epoch_acc

@torch.no_grad()
def validate(model, loader):
    model.eval()
    running_loss = 0.0
    agg = {"tn":0,"fp":0,"fn":0,"tp":0}
    
    for imgs, masks in tqdm(loader, desc="Val batch"):
        imgs = imgs.to(device)
        masks = masks.to(device)
        logits = model(imgs)
        loss = combined_loss(logits, masks)
        running_loss += loss.item() * imgs.size(0)
        metas = compute_metrics_batch(logits, masks)
        for k in ["tn","fp","fn","tp"]:
            agg[k] += metas[k]
    
    tp, fp, fn, tn = agg["tp"], agg["fp"], agg["fn"], agg["tn"]
    eps = 1e-8
    iou = tp / (tp + fp + fn + eps)
    iou_bg = tn / (tn + fp + fn + eps)
    miou = (iou + iou_bg) / 2
    dice = (2 * tp) / (2 * tp + fp + fn + eps)
    precision = tp / (tp + fp + eps)
    recall = tp / (tp + fn + eps)
    f1 = 2 * precision * recall / (precision + recall + eps)
    acc = (tp + tn) / (tp + tn + fp + fn + eps)
    
    epoch_loss = running_loss / len(loader.dataset)
    metrics = {"loss": epoch_loss, "iou": iou, "miou": miou, "dice": dice, "precision": precision,
               "recall": recall, "f1": f1, "acc": acc, 
               "confusion": np.array([[tn, fp], [fn, tp]])}
    return metrics

def plot_confusion_matrix(confusion_matrix, title='Confusion Matrix'):
    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Background', 'Solar Panel'], 
                yticklabels=['Background', 'Solar Panel'])
    plt.title(title)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig(f'{title.lower().replace(" ", "_")}.png', dpi=300, bbox_inches='tight')
    plt.show()

def train_model(model, train_loader, val_loader, num_epochs=200, learning_rate=2e-4, patience=10):
    decay, no_decay = [], []
    for name, p in model.named_parameters():
        if not p.requires_grad:
            continue
        if p.ndim == 1 or name.endswith(".bias"):
            no_decay.append(p)
        else:
            decay.append(p)

    optimizer = optim.AdamW(
        [
            {"params": decay, "weight_decay": 1e-4},
            {"params": no_decay, "weight_decay": 0.0},
        ],
        lr=learning_rate,
    )
    
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.7, patience=7, min_lr=1e-6
    )
    
    early_stopping = EarlyStopping(patience=patience, min_delta=1e-4)
    
    train_losses = []
    train_accs = []
    val_losses = []
    val_accs = []
    val_ious = []
    val_dices = []
    
    best_val_loss = float('inf')
    
    for epoch in range(num_epochs):
        print(f"\nEpoch {epoch+1}/{num_epochs}")
        
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer)
        val_metrics = validate(model, val_loader)
        
        scheduler.step(val_metrics['loss'])
        
        print(f"Train Loss: {train_loss:.6f} | Train Acc: {train_acc:.4f}")
        print(f"Val Loss: {val_metrics['loss']:.6f} | Val Acc: {val_metrics['acc']:.4f} | IoU: {val_metrics['iou']:.4f} | Dice: {val_metrics['dice']:.4f} | F1: {val_metrics['f1']:.4f}")
        print(f"Learning Rate: {optimizer.param_groups[0]['lr']:.2e}")
        
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        val_losses.append(val_metrics['loss'])
        val_accs.append(val_metrics['acc'])
        val_ious.append(val_metrics['iou'])
        val_dices.append(val_metrics['dice'])
        
        if val_metrics['loss'] < best_val_loss - 1e-4:
            best_val_loss = val_metrics['loss']
            torch.save(model.state_dict(), 'best_unet5_pv01.pth')
            print(f"Saved best model with validation loss: {best_val_loss:.6f}")
        
        if early_stopping(val_metrics['loss'], model):
            print(f'Early stopping triggered after {epoch+1} epochs')
            break
    
    return train_losses, train_accs, val_losses, val_accs, val_ious, val_dices

def main():
    BATCH_SIZE = 6
    LEARNING_RATE = 2e-4
    NUM_EPOCHS = 200
    PATIENCE = 10
    IMG_SIZE = (256, 256)
    FEATURES = [32, 64, 128, 256, 512]  # 5-level U-Net
    
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    # folder that contains PV01_Rooftop_Brick, PV01_Rooftop_FlatConcrete, PV01_Rooftop_SteelTile
    root_dir = '/kaggle/input/datasets/dewangchoudhary/pv01dataset/PV01/PV01'
    
    train_pairs, val_pairs, test_pairs = build_pv01_splits(root_dir, val_frac=0.15, test_frac=0.15, seed=42)
    train_dataset = PV01Dataset(train_pairs, transform=transform, img_size=IMG_SIZE)
    val_dataset = PV01Dataset(val_pairs, transform=transform, img_size=IMG_SIZE)
    test_dataset = PV01Dataset(test_pairs, transform=transform, img_size=IMG_SIZE)
    
    train_loader = DataLoader(train_dataset, batch_size=6, shuffle=True, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=2, shuffle=False, num_workers=0, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=0, pin_memory=True)
    
    print(f"Training samples: {len(train_dataset)}")
    print(f"Validation samples: {len(val_dataset)}")
    print(f"Test samples: {len(test_dataset)}")
    
    model = UNet(in_channels=3, out_channels=1, features=FEATURES, dropout_rate=0.15).to(device)
    
    total_params = sum(p.numel() for p in model.parameters())
    print(f"Total parameters: {total_params:,}")
    
    print("Starting training...")
    train_losses, train_accs, val_losses, val_accs, val_ious, val_dices = train_model(
        model, train_loader, val_loader, NUM_EPOCHS, LEARNING_RATE, PATIENCE
    )
    
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    ax1.plot(train_losses, label='Training Loss')
    ax1.plot(val_losses, label='Validation Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.set_ylim(0, 1)
    ax1.legend()
    ax1.set_title('Training and Validation Loss')
    
    ax2.plot(train_accs, label='Training Accuracy')
    ax2.plot(val_accs, label='Validation Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.set_ylim(0, 1)
    ax2.legend()
    ax2.set_title('Training and Validation Accuracy')
    
    ax3.plot(val_ious, label='Validation IoU', color='green')
    ax3.set_xlabel('Epoch')
    ax3.set_ylabel('IoU')
    ax3.set_ylim(0, 1)
    ax3.legend()
    ax3.set_title('Validation IoU')
    
    ax4.plot(val_ious, label='IoU', color='green')
    ax4.plot(val_dices, label='Dice', color='orange')
    ax4.set_xlabel('Epoch')
    ax4.set_ylabel('Score')
    ax4.set_ylim(0, 1)
    ax4.legend()
    ax4.set_title('Validation Metrics')
    
    plt.tight_layout()
    plt.savefig('training_curves.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print("Loading best model for test evaluation...")
    model.load_state_dict(torch.load('best_unet5_pv01.pth', map_location=device))
    model.to(device)
    
    print("\nEvaluating on test set...")
    test_metrics = validate(model, test_loader)
    
    print("\n" + "="*50)
    print("UNET5 TEST EVALUATION METRICS")
    print("="*50)
    print(f"Test set processed with batch_size=1")
    print(f"Loss:            {test_metrics['loss']:.6f}")
    print(f"IoU:             {test_metrics['iou']:.4f}")
    print(f"mIoU:            {test_metrics['miou']:.4f}")
    print(f"Dice Coefficient: {test_metrics['dice']:.4f}")
    print(f"Accuracy:        {test_metrics['acc']:.4f}")
    print(f"Precision:       {test_metrics['precision']:.4f}")
    print(f"Recall:          {test_metrics['recall']:.4f}")
    print(f"F1-Score:        {test_metrics['f1']:.4f}")
    print("Confusion matrix (pixel-level):")
    print(test_metrics["confusion"])
    print("="*50)
    
    plot_confusion_matrix(test_metrics["confusion"], "Test Set Confusion Matrix")
    
    print("Training and evaluation completed!")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# PV01_Rooftop_Brick: 138 pairs
# PV01_Rooftop_FlatConcrete: 413 pairs
# PV01_Rooftop_SteelTile: 94 pairs
# Training samples: 451
# Validation samples: 97
# Test samples: 97
# Total parameters: 31,100,513
# Starting training...
#
# Epoch 1/200
# Train batch: 100%|██████████| 76/76 [00:15<00:00,  5.02it/s]
# Val batch: 100%|██████████| 49/49 [00:03<00:00, 16.27it/s]
# Train Loss: 0.516127 | Train Acc: 0.7925
# Val Loss: 0.401367 | Val Acc: 0.9130 | IoU: 0.7332 | Dice: 0.8461 | F1: 0.8461
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.401367
#
# Epoch 2/200
# Train batch: 100%|██████████| 76/76 [00:12<00:00,  6.29it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.08it/s]
# Train Loss: 0.405399 | Train Acc: 0.8961
# Val Loss: 0.326303 | Val Acc: 0.9456 | IoU: 0.8373 | Dice: 0.9115 | F1: 0.9115
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.326303
#
# Epoch 3/200
# Train batch: 100%|██████████| 76/76 [00:12<00:00,  6.24it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.01it/s]
# Train Loss: 0.348124 | Train Acc: 0.9343
# Val Loss: 0.334329 | Val Acc: 0.9299 | IoU: 0.7690 | Dice: 0.8694 | F1: 0.8694
# Learning Rate: 2.00e-04
#
# Epoch 4/200
# Train batch: 100%|██████████| 76/76 [00:15<00:00,  4.98it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.19it/s]
# Train Loss: 0.321792 | Train Acc: 0.9390
# Val Loss: 0.280591 | Val Acc: 0.9324 | IoU: 0.8126 | Dice: 0.8966 | F1: 0.8966
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.280591
#
# Epoch 5/200
# Train batch: 100%|██████████| 76/76 [00:12<00:00,  6.06it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.65it/s]
# Train Loss: 0.287362 | Train Acc: 0.9470
# Val Loss: 0.250600 | Val Acc: 0.9577 | IoU: 0.8719 | Dice: 0.9316 | F1: 0.9316
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.250600
#
# Epoch 6/200
# Train batch: 100%|██████████| 76/76 [00:12<00:00,  5.96it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.18it/s]
# Train Loss: 0.255541 | Train Acc: 0.9533
# Val Loss: 0.210137 | Val Acc: 0.9703 | IoU: 0.9044 | Dice: 0.9498 | F1: 0.9498
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.210137
#
# Epoch 7/200
# Train batch: 100%|██████████| 76/76 [00:13<00:00,  5.82it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.37it/s]
# Train Loss: 0.238423 | Train Acc: 0.9581
# Val Loss: 0.191526 | Val Acc: 0.9689 | IoU: 0.9022 | Dice: 0.9486 | F1: 0.9486
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.191526
#
# Epoch 8/200
# Train batch: 100%|██████████| 76/76 [00:13<00:00,  5.70it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.07it/s]
# Train Loss: 0.213580 | Train Acc: 0.9650
# Val Loss: 0.162727 | Val Acc: 0.9719 | IoU: 0.9080 | Dice: 0.9518 | F1: 0.9518
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.162727
#
# Epoch 9/200
# Train batch: 100%|██████████| 76/76 [00:13<00:00,  5.54it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.03it/s]
# Train Loss: 0.198317 | Train Acc: 0.9668
# Val Loss: 0.138542 | Val Acc: 0.9763 | IoU: 0.9237 | Dice: 0.9603 | F1: 0.9603
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.138542
#
# Epoch 10/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.39it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.03it/s]
# Train Loss: 0.183107 | Train Acc: 0.9677
# Val Loss: 0.170486 | Val Acc: 0.9576 | IoU: 0.8733 | Dice: 0.9323 | F1: 0.9323
# Learning Rate: 2.00e-04
#
# Epoch 11/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.20it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.81it/s]
# Train Loss: 0.166483 | Train Acc: 0.9717
# Val Loss: 0.144114 | Val Acc: 0.9772 | IoU: 0.9258 | Dice: 0.9615 | F1: 0.9615
# Learning Rate: 2.00e-04
#
# Epoch 12/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.17it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.68it/s]
# Train Loss: 0.154945 | Train Acc: 0.9738
# Val Loss: 0.122780 | Val Acc: 0.9765 | IoU: 0.9241 | Dice: 0.9606 | F1: 0.9606
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.122780
#
# Epoch 13/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.42it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.38it/s]
# Train Loss: 0.145290 | Train Acc: 0.9733
# Val Loss: 0.115996 | Val Acc: 0.9758 | IoU: 0.9210 | Dice: 0.9588 | F1: 0.9588
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.115996
#
# Epoch 14/200
# Train batch: 100%|██████████| 76/76 [00:13<00:00,  5.47it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 27.73it/s]
# Train Loss: 0.139983 | Train Acc: 0.9736
# Val Loss: 0.144990 | Val Acc: 0.9669 | IoU: 0.8981 | Dice: 0.9463 | F1: 0.9463
# Learning Rate: 2.00e-04
#
# Epoch 15/200
# Train batch: 100%|██████████| 76/76 [00:13<00:00,  5.43it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.03it/s]
# Train Loss: 0.143424 | Train Acc: 0.9716
# Val Loss: 0.109232 | Val Acc: 0.9765 | IoU: 0.9246 | Dice: 0.9608 | F1: 0.9608
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.109232
#
# Epoch 16/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.33it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.26it/s]
# Train Loss: 0.132738 | Train Acc: 0.9740
# Val Loss: 0.096465 | Val Acc: 0.9786 | IoU: 0.9299 | Dice: 0.9637 | F1: 0.9637
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.096465
#
# Epoch 17/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.34it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.44it/s]
# Train Loss: 0.114500 | Train Acc: 0.9779
# Val Loss: 0.100370 | Val Acc: 0.9771 | IoU: 0.9246 | Dice: 0.9608 | F1: 0.9608
# Learning Rate: 2.00e-04
#
# Epoch 18/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.34it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.26it/s]
# Train Loss: 0.116883 | Train Acc: 0.9762
# Val Loss: 0.098142 | Val Acc: 0.9771 | IoU: 0.9255 | Dice: 0.9613 | F1: 0.9613
# Learning Rate: 2.00e-04
#
# Epoch 19/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.37it/s]
# Train Loss: 0.114439 | Train Acc: 0.9754
# Val Loss: 0.088150 | Val Acc: 0.9791 | IoU: 0.9321 | Dice: 0.9648 | F1: 0.9648
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.088150
#
# Epoch 20/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.37it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.47it/s]
# Train Loss: 0.103643 | Train Acc: 0.9788
# Val Loss: 0.090244 | Val Acc: 0.9785 | IoU: 0.9307 | Dice: 0.9641 | F1: 0.9641
# Learning Rate: 2.00e-04
#
# Epoch 21/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.34it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.63it/s]
# Train Loss: 0.100936 | Train Acc: 0.9775
# Val Loss: 0.087723 | Val Acc: 0.9801 | IoU: 0.9350 | Dice: 0.9664 | F1: 0.9664
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.087723
#
# Epoch 22/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.01it/s]
# Train Loss: 0.096295 | Train Acc: 0.9783
# Val Loss: 0.079528 | Val Acc: 0.9803 | IoU: 0.9357 | Dice: 0.9668 | F1: 0.9668
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.079528
#
# Epoch 23/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.36it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.86it/s]
# Train Loss: 0.093927 | Train Acc: 0.9779
# Val Loss: 0.074504 | Val Acc: 0.9806 | IoU: 0.9369 | Dice: 0.9674 | F1: 0.9674
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.074504
#
# Epoch 24/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.37it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.75it/s]
# Train Loss: 0.089380 | Train Acc: 0.9792
# Val Loss: 0.085712 | Val Acc: 0.9776 | IoU: 0.9271 | Dice: 0.9622 | F1: 0.9622
# Learning Rate: 2.00e-04
#
# Epoch 25/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.36it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.06it/s]
# Train Loss: 0.092699 | Train Acc: 0.9780
# Val Loss: 0.075387 | Val Acc: 0.9804 | IoU: 0.9361 | Dice: 0.9670 | F1: 0.9670
# Learning Rate: 2.00e-04
#
# Epoch 26/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.71it/s]
# Train Loss: 0.089428 | Train Acc: 0.9794
# Val Loss: 0.080106 | Val Acc: 0.9793 | IoU: 0.9319 | Dice: 0.9648 | F1: 0.9648
# Learning Rate: 2.00e-04
#
# Epoch 27/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.45it/s]
# Train Loss: 0.090374 | Train Acc: 0.9781
# Val Loss: 0.082554 | Val Acc: 0.9775 | IoU: 0.9266 | Dice: 0.9619 | F1: 0.9619
# Learning Rate: 2.00e-04
#
# Epoch 28/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.63it/s]
# Train Loss: 0.085996 | Train Acc: 0.9788
# Val Loss: 0.080724 | Val Acc: 0.9780 | IoU: 0.9282 | Dice: 0.9628 | F1: 0.9628
# Learning Rate: 2.00e-04
#
# Epoch 29/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.36it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.18it/s]
# Train Loss: 0.078744 | Train Acc: 0.9803
# Val Loss: 0.078858 | Val Acc: 0.9790 | IoU: 0.9314 | Dice: 0.9645 | F1: 0.9645
# Learning Rate: 2.00e-04
#
# Epoch 30/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.36it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.02it/s]
# Train Loss: 0.076603 | Train Acc: 0.9806
# Val Loss: 0.073921 | Val Acc: 0.9798 | IoU: 0.9340 | Dice: 0.9659 | F1: 0.9659
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.073921
#
# Epoch 31/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.82it/s]
# Train Loss: 0.074584 | Train Acc: 0.9803
# Val Loss: 0.074097 | Val Acc: 0.9782 | IoU: 0.9286 | Dice: 0.9630 | F1: 0.9630
# Learning Rate: 2.00e-04
#
# Epoch 32/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.34it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.81it/s]
# Train Loss: 0.072995 | Train Acc: 0.9803
# Val Loss: 0.071726 | Val Acc: 0.9799 | IoU: 0.9335 | Dice: 0.9656 | F1: 0.9656
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.071726
#
# Epoch 33/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.33it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.43it/s]
# Train Loss: 0.074046 | Train Acc: 0.9807
# Val Loss: 0.071895 | Val Acc: 0.9797 | IoU: 0.9343 | Dice: 0.9660 | F1: 0.9660
# Learning Rate: 2.00e-04
#
# Epoch 34/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.25it/s]
# Train Loss: 0.075346 | Train Acc: 0.9787
# Val Loss: 0.070676 | Val Acc: 0.9800 | IoU: 0.9342 | Dice: 0.9660 | F1: 0.9660
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.070676
#
# Epoch 35/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.41it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.01it/s]
# Train Loss: 0.071207 | Train Acc: 0.9804
# Val Loss: 0.066367 | Val Acc: 0.9798 | IoU: 0.9347 | Dice: 0.9662 | F1: 0.9662
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.066367
#
# Epoch 36/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.41it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.17it/s]
# Train Loss: 0.067839 | Train Acc: 0.9802
# Val Loss: 0.076454 | Val Acc: 0.9780 | IoU: 0.9279 | Dice: 0.9626 | F1: 0.9626
# Learning Rate: 2.00e-04
#
# Epoch 37/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.39it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.78it/s]
# Train Loss: 0.072502 | Train Acc: 0.9804
# Val Loss: 0.068309 | Val Acc: 0.9800 | IoU: 0.9354 | Dice: 0.9666 | F1: 0.9666
# Learning Rate: 2.00e-04
#
# Epoch 38/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.77it/s]
# Train Loss: 0.073803 | Train Acc: 0.9801
# Val Loss: 0.062395 | Val Acc: 0.9812 | IoU: 0.9391 | Dice: 0.9686 | F1: 0.9686
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.062395
#
# Epoch 39/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.27it/s]
# Train Loss: 0.076775 | Train Acc: 0.9800
# Val Loss: 0.065253 | Val Acc: 0.9814 | IoU: 0.9393 | Dice: 0.9687 | F1: 0.9687
# Learning Rate: 2.00e-04
#
# Epoch 40/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.34it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.86it/s]
# Train Loss: 0.065181 | Train Acc: 0.9813
# Val Loss: 0.061846 | Val Acc: 0.9816 | IoU: 0.9399 | Dice: 0.9690 | F1: 0.9690
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.061846
#
# Epoch 41/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.34it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.83it/s]
# Train Loss: 0.068389 | Train Acc: 0.9812
# Val Loss: 0.064974 | Val Acc: 0.9800 | IoU: 0.9355 | Dice: 0.9667 | F1: 0.9667
# Learning Rate: 2.00e-04
#
# Epoch 42/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.36it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.36it/s]
# Train Loss: 0.064456 | Train Acc: 0.9814
# Val Loss: 0.071532 | Val Acc: 0.9792 | IoU: 0.9316 | Dice: 0.9646 | F1: 0.9646
# Learning Rate: 2.00e-04
#
# Epoch 43/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.39it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.06it/s]
# Train Loss: 0.061033 | Train Acc: 0.9822
# Val Loss: 0.064545 | Val Acc: 0.9813 | IoU: 0.9388 | Dice: 0.9684 | F1: 0.9684
# Learning Rate: 2.00e-04
#
# Epoch 44/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.40it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 31.15it/s]
# Train Loss: 0.062133 | Train Acc: 0.9822
# Val Loss: 0.062460 | Val Acc: 0.9816 | IoU: 0.9400 | Dice: 0.9691 | F1: 0.9691
# Learning Rate: 2.00e-04
#
# Epoch 45/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.42it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.67it/s]
# Train Loss: 0.056808 | Train Acc: 0.9824
# Val Loss: 0.060704 | Val Acc: 0.9818 | IoU: 0.9403 | Dice: 0.9693 | F1: 0.9693
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.060704
#
# Epoch 46/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.39it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.59it/s]
# Train Loss: 0.057360 | Train Acc: 0.9825
# Val Loss: 0.073427 | Val Acc: 0.9793 | IoU: 0.9322 | Dice: 0.9649 | F1: 0.9649
# Learning Rate: 2.00e-04
#
# Epoch 47/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.71it/s]
# Train Loss: 0.057356 | Train Acc: 0.9823
# Val Loss: 0.067769 | Val Acc: 0.9807 | IoU: 0.9366 | Dice: 0.9673 | F1: 0.9673
# Learning Rate: 2.00e-04
#
# Epoch 48/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.34it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.14it/s]
# Train Loss: 0.055684 | Train Acc: 0.9829
# Val Loss: 0.077355 | Val Acc: 0.9770 | IoU: 0.9257 | Dice: 0.9614 | F1: 0.9614
# Learning Rate: 2.00e-04
#
# Epoch 49/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.77it/s]
# Train Loss: 0.066152 | Train Acc: 0.9817
# Val Loss: 0.072528 | Val Acc: 0.9789 | IoU: 0.9312 | Dice: 0.9644 | F1: 0.9644
# Learning Rate: 2.00e-04
#
# Epoch 50/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.36it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 31.29it/s]
# Train Loss: 0.056160 | Train Acc: 0.9830
# Val Loss: 0.060724 | Val Acc: 0.9812 | IoU: 0.9390 | Dice: 0.9686 | F1: 0.9686
# Learning Rate: 2.00e-04
#
# Epoch 51/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.40it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.87it/s]
# Train Loss: 0.054601 | Train Acc: 0.9835
# Val Loss: 0.059329 | Val Acc: 0.9819 | IoU: 0.9411 | Dice: 0.9696 | F1: 0.9696
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.059329
#
# Epoch 52/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.42it/s]
# Train Loss: 0.053553 | Train Acc: 0.9828
# Val Loss: 0.067278 | Val Acc: 0.9815 | IoU: 0.9390 | Dice: 0.9685 | F1: 0.9685
# Learning Rate: 2.00e-04
#
# Epoch 53/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.36it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 31.53it/s]
# Train Loss: 0.056994 | Train Acc: 0.9824
# Val Loss: 0.077479 | Val Acc: 0.9798 | IoU: 0.9334 | Dice: 0.9656 | F1: 0.9656
# Learning Rate: 2.00e-04
#
# Epoch 54/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.33it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.76it/s]
# Train Loss: 0.058651 | Train Acc: 0.9815
# Val Loss: 0.059113 | Val Acc: 0.9818 | IoU: 0.9409 | Dice: 0.9696 | F1: 0.9696
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.059113
#
# Epoch 55/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.41it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 31.07it/s]
# Train Loss: 0.052751 | Train Acc: 0.9831
# Val Loss: 0.066058 | Val Acc: 0.9812 | IoU: 0.9384 | Dice: 0.9682 | F1: 0.9682
# Learning Rate: 2.00e-04
#
# Epoch 56/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.42it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.85it/s]
# Train Loss: 0.052623 | Train Acc: 0.9826
# Val Loss: 0.060236 | Val Acc: 0.9815 | IoU: 0.9395 | Dice: 0.9688 | F1: 0.9688
# Learning Rate: 2.00e-04
#
# Epoch 57/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.39it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.45it/s]
# Train Loss: 0.051476 | Train Acc: 0.9836
# Val Loss: 0.066104 | Val Acc: 0.9809 | IoU: 0.9376 | Dice: 0.9678 | F1: 0.9678
# Learning Rate: 2.00e-04
#
# Epoch 58/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.86it/s]
# Train Loss: 0.051637 | Train Acc: 0.9838
# Val Loss: 0.063366 | Val Acc: 0.9817 | IoU: 0.9399 | Dice: 0.9690 | F1: 0.9690
# Learning Rate: 2.00e-04
#
# Epoch 59/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.33it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.89it/s]
# Train Loss: 0.049697 | Train Acc: 0.9837
# Val Loss: 0.058529 | Val Acc: 0.9821 | IoU: 0.9414 | Dice: 0.9698 | F1: 0.9698
# Learning Rate: 2.00e-04
# Saved best model with validation loss: 0.058529
#
# Epoch 60/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 31.57it/s]
# Train Loss: 0.059513 | Train Acc: 0.9825
# Val Loss: 0.059142 | Val Acc: 0.9820 | IoU: 0.9415 | Dice: 0.9698 | F1: 0.9698
# Learning Rate: 2.00e-04
#
# Epoch 61/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.94it/s]
# Train Loss: 0.050413 | Train Acc: 0.9836
# Val Loss: 0.067894 | Val Acc: 0.9815 | IoU: 0.9391 | Dice: 0.9686 | F1: 0.9686
# Learning Rate: 2.00e-04
#
# Epoch 62/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.37it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.80it/s]
# Train Loss: 0.050528 | Train Acc: 0.9833
# Val Loss: 0.059493 | Val Acc: 0.9826 | IoU: 0.9430 | Dice: 0.9706 | F1: 0.9706
# Learning Rate: 2.00e-04
#
# Epoch 63/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.76it/s]
# Train Loss: 0.048052 | Train Acc: 0.9840
# Val Loss: 0.060284 | Val Acc: 0.9825 | IoU: 0.9426 | Dice: 0.9704 | F1: 0.9704
# Learning Rate: 2.00e-04
#
# Epoch 64/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.34it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.45it/s]
# Train Loss: 0.050515 | Train Acc: 0.9834
# Val Loss: 0.060935 | Val Acc: 0.9815 | IoU: 0.9397 | Dice: 0.9689 | F1: 0.9689
# Learning Rate: 2.00e-04
#
# Epoch 65/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.39it/s]
# Train Loss: 0.051223 | Train Acc: 0.9834
# Val Loss: 0.063702 | Val Acc: 0.9813 | IoU: 0.9389 | Dice: 0.9685 | F1: 0.9685
# Learning Rate: 2.00e-04
#
# Epoch 66/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.35it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.61it/s]
# Train Loss: 0.054766 | Train Acc: 0.9824
# Val Loss: 0.063139 | Val Acc: 0.9808 | IoU: 0.9372 | Dice: 0.9676 | F1: 0.9676
# Learning Rate: 2.00e-04
#
# Epoch 67/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.36it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.48it/s]
# Train Loss: 0.049286 | Train Acc: 0.9841
# Val Loss: 0.063685 | Val Acc: 0.9822 | IoU: 0.9416 | Dice: 0.9699 | F1: 0.9699
# Learning Rate: 1.40e-04
#
# Epoch 68/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.37it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.75it/s]
# Train Loss: 0.045175 | Train Acc: 0.9847
# Val Loss: 0.065296 | Val Acc: 0.9816 | IoU: 0.9396 | Dice: 0.9688 | F1: 0.9688
# Learning Rate: 1.40e-04
#
# Epoch 69/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.42it/s]
# Train Loss: 0.042730 | Train Acc: 0.9850
# Val Loss: 0.056307 | Val Acc: 0.9826 | IoU: 0.9431 | Dice: 0.9707 | F1: 0.9707
# Learning Rate: 1.40e-04
# Saved best model with validation loss: 0.056307
#
# Epoch 70/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.39it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.53it/s]
# Train Loss: 0.043749 | Train Acc: 0.9849
# Val Loss: 0.056480 | Val Acc: 0.9828 | IoU: 0.9436 | Dice: 0.9710 | F1: 0.9710
# Learning Rate: 1.40e-04
#
# Epoch 71/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.03it/s]
# Train Loss: 0.042035 | Train Acc: 0.9852
# Val Loss: 0.063946 | Val Acc: 0.9818 | IoU: 0.9405 | Dice: 0.9694 | F1: 0.9694
# Learning Rate: 1.40e-04
#
# Epoch 72/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.39it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.68it/s]
# Train Loss: 0.041602 | Train Acc: 0.9853
# Val Loss: 0.058137 | Val Acc: 0.9826 | IoU: 0.9435 | Dice: 0.9709 | F1: 0.9709
# Learning Rate: 1.40e-04
#
# Epoch 73/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.39it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.82it/s]
# Train Loss: 0.039872 | Train Acc: 0.9856
# Val Loss: 0.060465 | Val Acc: 0.9831 | IoU: 0.9448 | Dice: 0.9716 | F1: 0.9716
# Learning Rate: 1.40e-04
#
# Epoch 74/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.96it/s]
# Train Loss: 0.040650 | Train Acc: 0.9856
# Val Loss: 0.059795 | Val Acc: 0.9824 | IoU: 0.9422 | Dice: 0.9702 | F1: 0.9702
# Learning Rate: 1.40e-04
#
# Epoch 75/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.36it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.93it/s]
# Train Loss: 0.045827 | Train Acc: 0.9843
# Val Loss: 0.060153 | Val Acc: 0.9824 | IoU: 0.9424 | Dice: 0.9703 | F1: 0.9703
# Learning Rate: 1.40e-04
#
# Epoch 76/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 30.62it/s]
# Train Loss: 0.041557 | Train Acc: 0.9853
# Val Loss: 0.059630 | Val Acc: 0.9818 | IoU: 0.9405 | Dice: 0.9694 | F1: 0.9694
# Learning Rate: 1.40e-04
#
# Epoch 77/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 31.62it/s]
# Train Loss: 0.041254 | Train Acc: 0.9852
# Val Loss: 0.058413 | Val Acc: 0.9823 | IoU: 0.9420 | Dice: 0.9701 | F1: 0.9701
# Learning Rate: 9.80e-05
#
# Epoch 78/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 28.01it/s]
# Train Loss: 0.041365 | Train Acc: 0.9856
# Val Loss: 0.061020 | Val Acc: 0.9827 | IoU: 0.9432 | Dice: 0.9708 | F1: 0.9708
# Learning Rate: 9.80e-05
#
# Epoch 79/200
# Train batch: 100%|██████████| 76/76 [00:14<00:00,  5.38it/s]
# Val batch: 100%|██████████| 49/49 [00:01<00:00, 29.48it/s]
# Train Loss: 0.039091 | Train Acc: 0.9858
# Val Loss: 0.059275 | Val Acc: 0.9828 | IoU: 0.9435 | Dice: 0.9709 | F1: 0.9709
# Learning Rate: 9.80e-05
# Early stopping triggered after 79 epochs
# Loading best model for test evaluation...
#
# Evaluating on test set...
# Val batch: 100%|██████████| 97/97 [00:04<00:00, 20.95it/s]
# ==================================================
# UNET5 TEST EVALUATION METRICS
# ==================================================
# Test set processed with batch_size=1
# Loss:            0.064600
# IoU:             0.9335
# mIoU:            0.9555
# Dice Coefficient: 0.9656
# Accuracy:        0.9830
# Precision:       0.9606
# Recall:          0.9707
# F1-Score:        0.9656
# Confusion matrix (pixel-level):
# [[4727634   62398]
#  [  45982 1520978]]
# ==================================================
# Training and evaluation completed!

# %%
import random

root_dir = '/kaggle/input/datasets/dewangchoudhary/pv01dataset/PV01/PV01'
IMG_SIZE = (256, 256)
FEATURES = [32, 64, 128, 256, 512]          # 5-level U-Net (must match training)
CKPT = 'best_unet5_pv01.pth'

# rebuild the same test set (fixed seed) and load the best checkpoint
_, _, test_pairs = build_pv01_splits(root_dir, val_frac=0.15, test_frac=0.15, seed=42)
tf = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
test_ds = PV01Dataset(test_pairs, transform=tf, img_size=IMG_SIZE)

model = UNet(in_channels=3, out_channels=1, features=FEATURES, dropout_rate=0.15).to(device)
model.load_state_dict(torch.load(CKPT, map_location=device))
model.eval()

mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)

def show_predictions(n=8, seed=0, thresh=0.5):
    random.seed(seed)
    idxs = random.sample(range(len(test_ds)), n)
    fig, axes = plt.subplots(n, 4, figsize=(14, 3.4 * n))
    for r, i in enumerate(idxs):
        img, gt = test_ds[i]
        with torch.no_grad():
            prob = torch.sigmoid(model(img.unsqueeze(0).to(device)))[0, 0].cpu()
        pred = (prob >= thresh).float()

        rgb = (img * std + mean).clamp(0, 1).permute(1, 2, 0).numpy()
        gt_np, pred_np = gt[0].numpy(), pred.numpy()

        inter = (gt_np * pred_np).sum()
        union = gt_np.sum() + pred_np.sum() - inter
        iou = inter / union if union > 0 else float('nan')

        overlay = rgb.copy()
        overlay[pred_np > 0] = 0.5 * overlay[pred_np > 0] + 0.5 * np.array([1, 0, 0])

        axes[r, 0].imshow(rgb);                  axes[r, 0].set_title("Image")
        axes[r, 1].imshow(gt_np, cmap='gray');   axes[r, 1].set_title("Ground truth")
        axes[r, 2].imshow(pred_np, cmap='gray'); axes[r, 2].set_title(f"Prediction (IoU {iou:.2f})")
        axes[r, 3].imshow(overlay);              axes[r, 3].set_title("Prediction overlay (red)")
        for a in axes[r]: a.axis('off')
    plt.tight_layout()
    plt.savefig('predictions_unet5.png', dpi=200, bbox_inches='tight')
    plt.show()

show_predictions(n=8, seed=0)
# Out:
# PV01_Rooftop_Brick: 138 pairs
# PV01_Rooftop_FlatConcrete: 413 pairs
# PV01_Rooftop_SteelTile: 94 pairs
